# %%
with open('o.txt', 'r') as f:
    data = f.readlines()
data = [i.split() for i in data]
for i in range(len(data)):
    for j in range(len(data[i])):
        data[i][j] = int(data[i][j])
        
diskReadsLRU = data[12]
diskReadsMRU = data[13]
diskReadsClock = data[14]

# %%
import matplotlib.pyplot as plt
frames = [i for i in range(2, 21)]
plt.plot(frames, diskReadsLRU, label='LRU')
plt.plot(frames, diskReadsMRU, label='MRU')
plt.plot(frames, diskReadsClock, label='Clock')
plt.scatter(frames, diskReadsLRU)
plt.scatter(frames, diskReadsMRU)
plt.scatter(frames, diskReadsClock)
plt.xlabel('Number of Frames in Buffer Pool')
plt.ylabel('Number of Disk Reads')
plt.legend()
plt.title('Disk Reads for Join Query')

plt.show()

# %%
diskReadsLRU = data[3]
diskReadsMRU = data[4]
diskReadsClock = data[5]
import matplotlib.pyplot as plt

plt.plot(frames, diskReadsLRU, label='LRU')
plt.plot(frames, diskReadsMRU, label='MRU')
plt.plot(frames, diskReadsClock, label='Clock')
plt.scatter(frames, diskReadsLRU)
plt.scatter(frames, diskReadsMRU)
plt.scatter(frames, diskReadsClock)
plt.xlabel('Number of Frames in Buffer Pool')
plt.ylabel('Number of Disk Reads')
plt.legend()
plt.title('Disk Reads for Select Query')

plt.show()

# %%
diskReadsLRU = data[15]
diskReadsMRU = data[16]
diskReadsClock = data[17]
import matplotlib.pyplot as plt

plt.plot(frames, diskReadsLRU, label='LRU')
plt.plot(frames, diskReadsMRU, label='MRU')
plt.plot(frames, diskReadsClock, label='Clock')
plt.scatter(frames, diskReadsLRU)
plt.scatter(frames, diskReadsMRU)
plt.scatter(frames, diskReadsClock)
plt.xlabel('Number of Frames in Buffer Pool')
plt.ylabel('Number of Page Hits')
plt.legend()
plt.title('Page Hits for Join Query')

plt.show()

# %%
diskReadsLRU = data[6]
diskReadsMRU = data[7]
diskReadsClock = data[8]
import matplotlib.pyplot as plt

plt.plot(frames, diskReadsLRU, label='LRU')
plt.plot(frames, diskReadsMRU, label='MRU')
plt.plot(frames, diskReadsClock, label='Clock')
plt.scatter(frames, diskReadsLRU)
plt.scatter(frames, diskReadsMRU)
plt.scatter(frames, diskReadsClock)
plt.xlabel('Number of Frames in Buffer Pool')
plt.ylabel('Number of Page Hits')
plt.legend()
plt.title('Page Hits for Select Query')

plt.show()
